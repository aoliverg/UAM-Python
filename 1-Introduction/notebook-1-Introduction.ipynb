# %% [markdown]
# # The Jupyter Notebook

# %% [markdown]
# The Jupyter Notebook is a web application that allows you to create and share documents that contain both text (in a format very similar to Wiki) and programming code (which in our case will be Python). With this web application, the code inserted in the document can be executed directly and the results observed.
#
# In this document, there are a couple of very simple examples. In the rest of course, a summary with the inserted code will be offered to be able to execute it directly.
#
# Notice that there is some code below, you can run it by selecting the cell containing the code and clicking on the icon representing the "play" symbol in the Jupyter menu or by doing Cell > Run cells.
#
# You can also modify the code or text and download a modified file from the File menu. This function allows you to download the file in different formats.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# Below you have another very simple example.

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %% [markdown]
# Using the Jupyter Notebook we can review the most important concepts of each module in an interactive interpreter.
